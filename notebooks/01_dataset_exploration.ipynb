# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

print("Notebook ready")
# Out:
# Notebook ready

# %%
# Change 'bottle' if you downloaded another category
CATEGORY = "bottle"
DATASET_PATH = "../data/mvtec_anomaly_detection"

TRAIN_GOOD_PATH = os.path.join(DATASET_PATH, "train", "good")
TEST_PATH = os.path.join(DATASET_PATH, "test")
GROUND_TRUTH_PATH = os.path.join(DATASET_PATH, "ground_truth")

print("Train good exists:", os.path.exists(TRAIN_GOOD_PATH))
print("Train normal images:", len(os.listdir(TRAIN_GOOD_PATH)))
print("Anomaly types:", os.listdir(GROUND_TRUTH_PATH))
# Out:
# Train good exists: False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 10
#       7 GROUND_TRUTH_PATH = os.path.join(DATASET_PATH, "ground_truth")
#       9 print("Train good exists:", os.path.exists(TRAIN_GOOD_PATH))
# ---> 10 print("Train normal images:", len(os.listdir(TRAIN_GOOD_PATH)))
#      11 print("Anomaly types:", os.listdir(GROUND_TRUTH_PATH))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/mvtec_anomaly_detection/train/good'

# %%
import os
print("Current working directory:")
print(os.getcwd())

print("\nFiles here:")
print(os.listdir())
# Out:
# Current working directory:
# /Users/aryanjadhav
#
# Files here:
# ...
